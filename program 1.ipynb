# %%
n=int(input("enter first number:"))
a=int(input("enter second number:"))
print("sum=",n+a)
print("multiple=",n*a)#using function return true if 2 list have atleast one common value
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False

list1 = [1, 2, 3, 4]
list2 = [5, 6, 3, 8]

print(common_member(list1, list2))
print("division=",n/a)
print("substraction=",n-a)
print("square of first number:",n**2)
# Out:
# enter first number:5
# enter second number:10
# sum= 15
# multiple= 50
# division= 0.5
# substraction= -5
# square of first number: 25

# %%
text=input("enter a  first name:")
tex1=input("enter a second name:")
print("uppercase:",tex1.upper())
print("lowercase:",text.lower())
print("concatination:",text+" "+tex1)
print("length:",len(text))
print(f"my name is {text} and last name is {tex1}")
print("capitalize second tearm:",tex1.capitalize())
print("center in first name:",text.center(10))
print("replace first name:",text.replace("a","x"))
print("strip first text:",text.strip(" "))
print("repetation of text :",tex1*4)
# Out:
# enter a  first name:            nefla
# enter a second name:fathima
# uppercase: FATHIMA
# lowercase:             nefla
# concatination:             nefla fathima
# length: 17
# my name is             nefla and last name is fathima
# capitalize second tearm: Fathima
# center in first name:             nefla
# replace first name:             neflx
# strip first text: nefla
# repetation of text : fathimafathimafathimafathima

# %%
n=list(input("enter animal name:").split(","))
print("list",n)
print("last animal:",n[-1])
print("first two animal:",n[0:2])
print("first animal:",[0])
n.append("elephant")
print("append:",n)
n.pop(1)
print("pop:",n)
rep=print("enter new color replace new position1:")
n[1]=rep
print("after replace:",n)
# Out:
# enter animal name:cat,dog,cow,goat
# list ['cat', 'dog', 'cow', 'goat']
# last animal: goat
# first two animal: ['cat', 'dog']
# first animal: [0]
# append: ['cat', 'dog', 'cow', 'goat', 'elephant']
# pop: ['cat', 'cow', 'goat', 'elephant']
# enter new color replace new position1:
# after replace: ['cat', None, 'goat', 'elephant']

# %%
color=input("enter some colors:")
colrss=list(color.split(","))
for col in colrss:
    print(col)
# Out:
# enter some colors:red,blue,black,yellow
# red
# blue
# black
# yellow

# %%
num=int(input("enter any range:"))
for i in range(num):
    print(i)
    #using function return true if 2 list have atleast one common value
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False

list1 = [1, 2, 3, 4]
list2 = [5, 6, 3, 8]

print(common_member(list1, list2))
# Out:
# enter any range:5
# 0
# 1
# 2
# 3
# 4

# %%
student= {
    "name":"ammu",
    "age":"22",
    "grade":"A"
}
print(student["name"])
print(student["age"])
student["city"]="uk"
student["age"] = 22
for key,value in student.items():
    print(key,value)
# Out:
# ammu
# 22
# name ammu
# age 22
# grade A
# city uk

# %%
#loop
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
#using function return true if 2 list have atleast one common value
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False

list1 = [1, 2, 3, 4]
list2 = [5, 6, 3, 8]

print(common_member(list1, list2))
if num1>num2:
    print("The num1 is grater:",num1)
else:
    print("The num2 is grater:",num2)
# Out:
# Enter first number:444
# Enter second number:89
# The num1 is grater: 444

# %%
#tuple
my_tuple = input("Enter the tuple numbers separated by commas:")
reversed_tuple = my_tuple[::-1]
print(my_tuple)
print(reversed_tuple)
# Out:
# Enter the tuple numbers separated by commas:3,5,6,7,8
# 3,5,6,7,8
# 8,7,6,5,3

# %%
#functiion
num=int(input("Enter a number:"))

def factorial(num):
    return[i for i in range(1,num+1) if num%i==0]

print("The factorial of the number",num, " is:",factorial(num))
# Out:
# Enter a number:55
# The factorial of the number 55  is: [1, 5, 11, 55]

# %%
#set
set1=set(input("Enter any color names (set1):").split(" "))
set2=set(input("Enter any color names (set2):").split(" "))

difference_set= set1.difference(set2)
print("set1 is:",set1)
print("set2 is:",set2)
print("colors not in set2 is:",difference_set)
# Out:
# Enter any color names (set1):2 3 4 5 7
# Enter any color names (set2):4 6 7 9 0
# set1 is: {'3', '4', '2', '7', '5'}
# set2 is: {'9', '4', '7', '6', '0'}
# colors not in set2 is: {'2', '5', '3'}

# %%
#dict
Rno=input("Enter the roll number for 3 students [using space]:").split(" ")
Rno1=list(map(int,Rno))
names=input("Enter 3 students names [using space]:").split(" ")

students=dict(zip(Rno,names))
print("Students with Roll_numbers:",students)

Rno2=input("Enter the roll number for 2 students:").split(" ")
Rno3=list(map(int,Rno))
names1=input("Enter 2 students names:").split(" ")

students1=dict(zip(Rno3,names1))
print("Students with Roll_numbers:",students1)

students.update(students1)
print("Merged dictionary:",students)
# Out:
# Enter the roll number for 3 students [using space]:17 22 13
# Enter 3 students names [using space]:nefla shaikha nayyira
# Students with Roll_numbers: {'17': 'nefla', '22': 'shaikha', '13': 'nayyira'}
# Enter the roll number for 2 students:3 8
# Enter 2 students names:nadi naji
# Students with Roll_numbers: {17: 'nadi', 22: 'naji'}
# Merged dictionary: {'17': 'nefla', '22': 'shaikha', '13': 'nayyira', 17: 'nadi', 22: 'naji'}

# %%
#largets number from list
numbers = [10, 25, 8, 42, 17]

largest = max(numbers)

print("Largest number:", largest)
# Out:
# Largest number: 42

# %%
#remove duplicates
numbers = [1, 2, 2, 3, 4, 4, 5]

unique = list(set(numbers))

print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
#convert tuple to dict
keys = ("a", "b", "c")
values = (1, 2, 3)

d = dict(zip(keys, values))

print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#using function return true if 2 list have atleast one common value
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False

list1 = [1, 2, 3, 4]
list2 = [5, 6, 3, 8]

print(common_member(list1, list2))
# Out:
# True
